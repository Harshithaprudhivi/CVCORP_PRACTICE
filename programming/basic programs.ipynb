# %%
#1.	Write a program to convert kg to g. (Input 5.6kg print in grams)
n=float(input("enter the weight in kgs"))
kg_g=int(n*1000)
print(f"the weight {n} kg is converted into {kg_g} grams")
# Out:
# the weight 5.6 kg is converted into 5600 grams

# %%
#2. Write a program to covert temperature from degree C to F. (Input 80C)		(80°C × 9/5) + 32 = 176°F

temp = float(input("enter the temperature in C:"))
F = (temp * 9/5)+32
c_f = temp * F
print(f"the temperature in {temp} C is converted into {c_f:.2f}F")
# Out:
# the temperature in 36.55 C is converted into 3574.22F

# %%
#3.	Declare and initialize 3 three variable and print the biggest number.
a=int(input("enter a:"))
b=int(input("enter b:"))
c=int(input("enter c:"))
if a>b and a>c:
    print(f"a = {a} is the biggest number")
elif b>c:
    print(f"b = {b} is the biggest number")
else:
    print(f"c = {c} is the biggest number")
# Out:
# c = 76 is the biggest number

# %%
# 4.	Write a Python program that performs the following tasks.
# a.	Store a number in a variable
# b.	If value is not in range (100-1000) prints wrong number else follows the steps
# c.	Check even or odd
# d.	If even divide the number by 3 and print the remainder
# e.	If odd divide the number by 2 and print the remainder.

a=int(input("enter a number:"))
if a>=100 and a<=1000:
    if a%2==0:
        print("even")
        print("remainder:",a%3)
    else:
        print("odd")
        print("remainder:",a%2)
else:
    print("wrong number")
# Out:
# odd
# remainder: 1

# %%
#5.	Declare & initialize a number. Check whether the number is in range 0-100 or not. If not in range print invalid input. Else – if the number is in range 91-100 then print Super Smart, 81-90 print Smart,71-80 print smart enough, 61-70 print just smart, 36-60 print no smart, 0-35 print dump.

num=int(input("enter the marks:"))
if num >= 0 and num<=100:
    if (num <=100 and num >=91):
        print("super smart")
    elif (num <=90 and num >=81):
        print("smart")
    elif (num <=80 and num >=71):
        print("smart enough")
    elif (num >=61 and num<=70):
        print("just smart")
    elif (num <=60 and num>=36):
        print("no smart")
    else:
        print("dump")
else:
    print("invalid input")
# Out:
# dump

# %%
#6.	Write a program to perform simple math based on the user inputs.(+ , - , * , /)
a=int(input("enter a value:"))
b=int(input("enter b value:"))
operator = input("enter the operator:")
if operator == "+":
    print("result =" , a+b)
elif operator == "-":
    print("result = ",a-b)
elif operator == "*":
    print("result =",a*b)
elif operator=="/":
    print("result =",a/b)

else:
    print("Invalid Input")
# Out:
# result = 0.9375

# %%
#7.	Write a program to print CVCORP for 33 times.
n= int(input("enter n value"))
for i in range(1,n+1):
    print("CVCORP")
# Out:
# CVCORP
# CVCORP
# CVCORP
# CVCORP
# CVCORP
# CVCORP
# CVCORP
# CVCORP
# CVCORP
# CVCORP

# %%
#8.	Write a program to print all numbers which are divisible by 11 from 250 to 550.
# for i in range(250, 551):
#     if i%11==0:
#         print(i)

a=int(input("enter a:"))
b=int(input("enter b:"))
for i in range(a,b+1):
    if i%11==0:
        print(i)
# Out:
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198

# %%
#9.	Write a program to sum all the numbers from 56 to 153.
sum_total=0
for i in range(56,155):
    sum_total+=i
print(sum_total)
# Out:
# 10395

# %%
#9.	Write a program to sum all the even numbers from 56 to 153.
a=int(input("a:"))
b=int(input("b:"))
sum_total=0
for i in range(a,b+1):
    if i%2==0:
        sum_total+=i
print("sum =",sum_total)
# Out:
# sum = 420

# %%
#10.	Write a program to print all even numbers in range 700 to 900.
for i in range(700,901):
    if i%2==0:

        print(i)
# Out:
# 700
# 702
# 704
# 706
# 708
# 710
# 712
# 714
# 716
# 718
# 720
# 722
# 724
# 726
# 728
# 730
# 732
# 734
# 736
# 738
# 740
# 742
# 744
# 746
# 748
# 750
# 752
# 754
# 756
# 758
# 760
# 762
# 764
# 766
# 768
# 770
# 772
# 774
# 776
# 778
# 780
# 782
# 784
# 786
# 788
# 790
# 792
# 794
# 796
# 798
# 800
# 802
# 804
# 806
# 808
# 810
# 812
# 814
# 816
# 818
# 820
# 822
# 824
# 826
# 828
# 830
# 832
# 834
# 836
# 838
# 840
# 842
# 844
# 846
# 848
# 850
# 852
# 854
# 856
# 858
# 860
# 862
# 864
# 866
# 868
# 870
# 872
# 874
# 876
# 878
# 880
# 882
# 884
# 886
# 888
# 890
# 892
# 894
# 896
# 898
# 900

# %%
#finding average of numbers in a range
a=int(input("a:"))
b=int(input("b:"))
sum=0
c=0
for i in range(a,b+1):
    sum=sum+i
    c=c+1
print(sum/c)
# Out:
# 15.0

# %%
a=float(input("a:"))
b=float(input("b:"))
sum_t=0
c=0
for i in range(a,b+1):
    if i%2==0:
        sum_t =  sum_t +i
        c+=1

avg = print("average:",sum_t/c)
# Out:
# average: 4.0

# %%
#Write a program to print all numbers which are divisible by 11 in given range if no such numbers print NO NUMBERS if starting range is greater than ending range then print INVALID RANGE

a=int(input())
b=int(input())
if a>b:
    print("Invalid Input")
else:
    c=0
    for i in range(a,b+1):
        if i%11==0:
            print(i)
            c+=1
    if c==0:
        print("No numbers")
# Out:
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99

# %%
n=7
for i in range(n):
    print
