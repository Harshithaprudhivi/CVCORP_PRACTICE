# %%
# Given two lists:
# a = [1, 2, 3, 4] b = [10, 20, 30, 40]
# Use map() with a lambda to create a new list containing the sum of corresponding elements.
a=[1,2,3,4]
b=[10,20,30,40]

li = list(map(lambda x,y:x+y,a,b))
print(li)
# Out:
# [11, 22, 33, 44]

# %%
#What happens if the lists are of unequal length?
a=[1,2,3,4]
b=[10,20,30,40,50]
li=list(map(lambda x,y:x+y,a,b))
print(li)
# Out:
# [11, 22, 33, 44]

# %%
# 3. Given a list:
# nums = [12, 15, 7, 18, 20, 21, 25]
# Use filter() and lambda to keep numbers that are divisible by 3 OR divisible by 5 but NOT divisible by both.
nums=[12,15,7,18,20,21,25]
li=list(filter(lambda x: (x%3==0 or x%5==0) and not (x%3==0 and x%5==0),nums))
li
# Out:
# [12, 18, 20, 21, 25]

# %%
# 4. Given a list:
# nums = [1, 2, 3, 4]
# Use reduce() with a lambda to compute the sum, but start with an initial value of 10.
from functools import reduce
nums =[1,2,3,4]
k=reduce(lambda x,y:x+y,nums,10)
print(k)
# Out:
# 20

# %%
nums =[[1,2],[3,4],[5,6]]
result = list(map(lambda x:x.append(10),nums))
print("result:",result)
print("Nums:",nums)
# Out:
# result: [None, None, None]
# Nums: [[1, 2, 10], [3, 4, 10], [5, 6, 10]]

# %%
#1.  Use map() with a lambda to add 5 to every element of the following nested
l1= [[1, 2], [3, 4], [5, 6]]
r=list(map(lambda sublist:list(map(lambda x:x+5,sublist)),l1))
print(r)
# Out:
# [[6, 7], [8, 9], [10, 11]]

# %%
#2.  Given a dictionary: d = {"apple": 100, "banana": 40, "cherry": 150} . Use filter() to keep only the keys whose values are greater than 50

d={"apple":100,"banana":40,"cherry":150}
r = list(filter(lambda item:item[1] >50,d.items()))
print(r)
# Out:
# [('apple', 100), ('cherry', 150)]

# %%
#3.  Use functools.reduce() with a lambda to find the largest number from a given list Dynamically.
#li=[10,22,21,34,23,45,20]
li=list(map(int,input("enter the list").split()))
s=reduce(lambda x,y:x if x>y else y,li)
print("largest number:",s)
# Out:
# largest number: 56

# %%
#4.  What happens if the lambda passed to reduce() accepts only one parameter or three parameters? Explain the output or error.
nums =[1,2,3]
d=reduce(lambda x:x+1,nums)
print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 #4.  What happens if the lambda passed to reduce() accepts only one parameter or three parameters? Explain the output or error.
#       2 nums =[1,2,3]
# ----> 3 d=reduce(lambda x:x+1,nums)
#       4 print(d)
#
# TypeError: <lambda>() takes 1 positional argument but 2 were given

# %%
nums=[1,2,3]
r=reduce(lambda x,y,z:x+y+z,nums)
print(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 nums=[1,2,3]
# ----> 2 r=reduce(lambda x,y,z:x+y+z,nums)
#       3 print(r)
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
nums=[1,2,3]
r=reduce(lambda x,y:x+y,nums)
print(r)
# Out:
# 6

# %%
#5.  Use map() on a string to convert each character into its ASCII value (using ord()). Print the result list.
text = input("enter a string:")
result = list(map(lambda ch:ord(ch),text))
print(result)
# Out:
# [104, 97, 114, 115, 104, 105, 116, 104, 97]

# %%
#6.  Use filter() to remove all vowels from a string and print the final string.
text =input("enter a text:")
r=list(filter(lambda x:x not in 'aeiouAEIOU',text))
print(r)
# Out:
# ['h', 'r', 's', 'h', 't', 'h']

# %%
# 7.  Use reduce() to concatenate a list of characters into a single string.
li=['P', 'y', 't', 'h', 'o', 'n']
r=reduce(lambda x,y:x+y,li)
print(r)
# Out:
# Python

# %%
#8.  Given a list of integers, use map() with id() to print the memory addressof each element. Example: [10, 350, 10, 350, 20] — explain why some addresses repeat.
li = [10,350,10,350,20]
t=list(map(lambda x:id(x),li))
print(t)
# Out:
# [140724081816984, 2688588055984, 140724081816984, 2688588055984, 140724081817304]

# %%
# 9.  Explain the difference between:
# map(str, [1, 2, 3])
# map(lambda x: str(x), [1, 2, 3])
# Which one is faster and why?

e=list(map(str,[1,2,3]))  #this is faster because str() is a inbuilt function
print(e)
# Out:
# ['1', '2', '3']

# %%
f=list(map(lambda x:str(x),[1,2,3]))
print(f)
# Out:
# ['1', '2', '3']

# %%
# 10.  Given a list of numbers:
# [5, 10, 15, 20, 25, 30]
# Perform the following in a single pipeline:
# • Use map() to square each number
# • Use filter() to keep only numbers divisible by 5
# • Use reduce() to calculate the sum of remaining number
l=[5,10,15,20,25,30]
c=reduce(lambda x,y:x+y,filter(lambda x:x%5==0,map(lambda x:x**2,l)))
print(c)
# Out:
# 2275
