# %%
def fun7(*a):
    i=0
    s=0
    while i<len(a):
        if a[i]%2==0:
            s+=a[i]
        i+=1
    print(s)
fun7(2,3,4,56,65,44,32)
# Out:
# 138

# %%
def fun8(*a):
    i=0
    s=0
    while i<len(a):
        s+=a[i]
        i+=2
    print(s)
fun8(1,23,5,6,4,3,10)
# Out:
# 20

# %%
def func8(*a):
    i=
    s=0
    while i <len(a):
        s+=a[i]
        i+=2

    print(s)
fun8(1,2,3,4,5,6,7,8)
# Out:
# 16

# %%
def fun6(*a):
    i=0
    s=0
    while i <len(a):
        if i%2==0:
            s+=a[i]
        i+=1

    print(s)
fun6(1,2,3,5,6,7,8)
# Out:
# 14

# %%
def fun6(*a):
    i=0
    s=0
    while i <len(a):
        if i%2!=0:
            s+=a[i]
        i+=1

    print(s)
fun6(1,2,3,5,6,7,8)
# Out:
# 14
